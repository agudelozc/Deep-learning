# %%
import numpy as np

# %% [markdown]
# SCALAR

# %%
x = np.array(42)
print(x.shape)
x.ndim

# %% [markdown]
# VECTOR

# %%
x = np.array([1,1,1,1,1])
print(x.shape)
x.ndim

# %% [markdown]
# MATRIZ

# %%
x = np.array([1,1,1,1,1])
print(x.shape)
x.ndim

# %% [markdown]
# TENSOR

# %%
x = np.array([1,1,1,1,1])
print(x.shape)
x.ndim

# %% [markdown]
# RESHAPE

# %%
x = np.array([[0,1],[0,10],[2,5]])
x.shape
# Out:
# (3, 2)

# %%
x.reshape(1,6)
# Out:
# array([[ 0,  1,  0, 10,  2,  5]])
