# %%
import torch
import torch.nn as nn

linear = nn.Linear(in_features = 4096, out_features = 10) # tensores de dim 1 input
conv = nn.Conv2d(in_channels=3, out_channels = 9, kernel_size=3, stride = 1,padding = 1) #modifcar canales pero no el tamaño
relu = nn.ReLU(False)

# %%
x = torch.randn(4096)
y = linear(x)
y.size()
# Out:
# torch.Size([10])

# %%
x = torch.randn(1,3,7,7)
y = conv(x)
z = relu(x)

# %%
y.size()
# Out:
# torch.Size([1, 9, 7, 7])

# %%
z
# Out:
# tensor([[[[8.1788e-01, 6.4612e-04, 0.0000e+00, 1.9899e-01, 9.3264e-01,
#            1.2129e+00, 0.0000e+00],
#           [0.0000e+00, 4.5645e-01, 6.2087e-02, 2.7464e-01, 7.5233e-01,
#            1.7127e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 2.3253e-01, 1.9613e+00, 1.8453e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 1.6377e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#            0.0000e+00, 3.8739e+00],
#           [0.0000e+00, 3.8152e-02, 0.0000e+00, 0.0000e+00, 1.6860e+00,
#            1.5771e+00, 9.8823e-01],
#           [1.4713e+00, 3.1287e-01, 9.7018e-01, 0.0000e+00, 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.1848e+00, 3.8330e-01, 0.0000e+00, 1.5377e-01, 1.4991e+00,
#            1.2079e-01, 0.0000e+00]],
#
#          [[0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0479e-03, 0.0000e+00,
#            1.5118e+00, 3.0445e-01],
#           [2.6421e-01, 8.4918e-01, 9.4687e-02, 0.0000e+00, 2.8772e-01,
#            9.0651e-02, 1.1893e-01],
#           [0.0000e+00, 8.8807e-01, 5.3649e-01, 4.2233e-01, 0.0000e+00,
#            4.3835e-01, 8.4280e-01],
#           [6.5964e-01, 5.7646e-01, 0.0000e+00, 0.0000e+00, 9.7477e-03,
#            1.3977e-01, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 1.0078e+00, 1.0279e+00, 0.0000e+00,
#            1.1435e+00, 6.0031e-01],
#           [0.0000e+00, 1.4660e+00, 0.0000e+00, 1.6410e+00, 9.2584e-01,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 9.1489e-01, 1.0534e+00, 6.7572e-01, 1.0433e+00,
#            1.6544e+00, 6.7885e-01]],
#
#          [[6.1113e-01, 8.8959e-01, 0.0000e+00, 4.0291e-01, 5.5664e-01,
#            0.0000e+00, 1.6592e+00],
#           [0.0000e+00, 1.4926e-01, 0.0000e+00, 6.0680e-01, 7.0629e-01,
#            1.4567e+00, 3.5844e-01],
#           [0.0000e+00, 5.8155e-01, 0.0000e+00, 3.2742e-02, 6.8910e-01,
#            3.2792e-01, 4.2156e-02],
#           [0.0000e+00, 1.7905e-01, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.5008e-01, 0.0000e+00, 0.0000e+00, 0.0000e+00, 8.1331e-01,
#            0.0000e+00, 2.7781e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 8.0465e-01,
#            2.6497e+00, 0.0000e+00],
#           [1.4993e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#            1.1592e+00, 0.0000e+00]]]])

# %%
for name, p in linear.named_parameters():
  print(name)
  print(p.size)
# Out:
# weight
# <built-in method size of Parameter object at 0x7f42a62bd3b0>
# bias
# <built-in method size of Parameter object at 0x7f4234db8e00>
